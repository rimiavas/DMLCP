# %% [markdown]
# # A simple face detection example
#
# Let's finally look at a simple face landmark detection example in Python. We will use the [mlxtend](http://rasbt.github.io/mlxtend/) package, which gives a simple interface to a number of machine learning algorithms and utilities. Under the hood, this example uses a face detector from the [dlib](http://dlib.net) library.
# First let's make sure we have `mlxtend` installed by using the relevant [conda](https://anaconda.org/conda-forge/mlxtend) package:
#
#     conda install -c conda-forge dlib
#     conda install -c conda-forge mlxtend
#
# We can then import the face detection utility:
#
# Or **if you are working in google collab**:

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: setuptools in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from mlxtend) (65.4.1)
# Requirement already satisfied: numpy>=1.16.2 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from mlxtend) (3.6.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from mlxtend) (1.1.3)
# Requirement already satisfied: scipy>=1.2.1 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from mlxtend) (1.8.1)
# Requirement already satisfied: joblib>=0.13.2 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.6)
# Requirement already satisfied: pytz>=2020.1 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2022.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /Users/colormotor/opt/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
from mlxtend.image import extract_face_landmarks

# %% [markdown]
# Finding the face landmarks is just one line of code:

# %%
landmarks = extract_face_landmarks(filtered_img)
print(landmarks)
# Out:
# #+begin_example
# [[154 211]
#  [157 248]
#  [165 286]
#  [176 321]
#  [194 353]
#  [217 382]
#  [247 404]
#  [281 418]
#  [317 421]
#  [347 414]
#  [367 392]
#  [380 362]
#  [387 330]
#  [393 298]
#  [400 268]
#  [404 238]
#  [402 208]
#  [204 179]
#  [227 169]
#  [251 167]
#  [275 171]
#  [297 180]
#  [340 180]
#  [355 172]
#  [371 167]
#  [388 166]
#  [400 174]
#  [321 198]
#  [324 218]
#  [328 239]
#  [333 260]
#  [302 285]
#  [314 287]
#  [326 289]
#  [335 287]
#  [344 283]
#  [235 201]
#  [250 193]
#  [266 192]
#  [278 202]
#  [265 207]
#  [249 207]
#  [343 202]
#  [356 192]
#  [371 192]
#  [380 200]
#  [372 207]
#  [357 206]
#  [278 344]
#  [297 333]
#  [315 326]
#  [325 329]
#  [334 326]
#  [343 331]
#  [350 341]
#  [343 349]
#  [335 353]
#  [325 355]
#  [315 355]
#  [297 352]
#  [287 344]
#  [315 340]
#  [324 341]
#  [334 339]
#  [343 341]
#  [334 335]
#  [325 338]
#  [316 337]]
# #+end_example

# %% [markdown]
# We can now plot the landmarks

# %%
plt.figure(figsize=(15, 5))
ax = plt.subplot(1, 3, 1)
plt.title("Input image")
plt.imshow(filtered_img)

plt.title("Landmarks")
ax = plt.subplot(1, 3, 2)
plt.scatter(landmarks[:, 0], landmarks[:, 1])
ax.invert_yaxis()
plt.axis('equal')

plt.subplot(1, 3, 3)
plt.title("Landmarks and image")
plt.imshow(filtered_img)
plt.scatter(landmarks[:, 0], landmarks[:, 1], alpha=0.8)
plt.show()

# %% [markdown]
# This code has three new Matplotlib functions we have not seen earlier. The `plt.scatter` functions creates what is known as a &ldquo;scatterplot&rdquo;, essentially it will just plot a circle for each point in the input. This is followed by a `ax.invert_yaxis()` function that flips the vertical axis so increasing coordinates go towards the bottom (the same convention used in P5js). Finally we use `ax.axis('equal')` to tell Matplotlib that we want it to maintain a fixed 1:1 aspect ratio for the plot. Try to comment these last two lines and see how the plot changes.
